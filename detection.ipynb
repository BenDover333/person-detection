# %%
from ultralytics import YOLO
import cv2
import math

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
# Out:
# True

# %%
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person"]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 56.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 56.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 74.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.7ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.4ms preprocess, 73.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.1ms preprocess, 68.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.5ms preprocess, 61.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.2ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.5ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.4ms preprocess, 59.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.7ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.2ms preprocess, 52.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.7ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.2ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.9ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.1ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.3ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.8ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.7ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.3ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 53.2ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.2ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 52.1ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.2ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 66.4ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.8ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.7ms preprocess, 67.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.3ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 1.4ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.9ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.3ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.7ms preprocess, 58.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.1ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.3ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.3ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 1.2ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 53.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 dog, 55.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.42
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 20
#      17 print("Confidence --->",confidence)
#      19 cls = int(box.cls[0])
# ---> 20 print("Class name -->", classNames[cls])
#      22 org = [x1, y1]
#      23 font = cv2.FONT_HERSHEY_SIMPLEX
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
classNames = ["person"]

cv2.namedWindow("preview")
vc = cv2.VideoCapture(0)

if vc.isOpened():
    rval, frame = vc.read()
else:
    rval = False

while rval:

    results = model(frame, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(frame, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow("preview", frame)
    rval, frame = vc.read()
    key = cv2.waitKey(20)
    if key == 27: # exit on ESC
        break

vc.release()
cv2.destroyWindow("preview")
# Out:
# 0: 480x640 1 person, 105.9ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.2ms preprocess, 105.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.8ms preprocess, 77.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.0ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.6ms preprocess, 75.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.3ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.3ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.5ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.2ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 63.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.9ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.6ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.4ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.0ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.2ms preprocess, 59.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 73.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 61.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.4ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.2ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.4ms preprocess, 65.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.2ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.1ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.1ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 2.0ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.4ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.4ms preprocess, 67.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.3ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.4ms preprocess, 61.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.3ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.2ms preprocess, 81.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.3ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.5ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.6ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.0ms preprocess, 59.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.2ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.3ms preprocess, 60.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 57.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 63.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 60.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 52.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 59.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.8ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.2ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 54.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.4ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 53.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 63.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.8ms preprocess, 110.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.4ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.8ms preprocess, 61.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.2ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.3ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 53.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 58.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 54.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 28
#      25 print("Confidence --->",confidence)
#      27 cls = int(box.cls[0])
# ---> 28 print("Class name -->", classNames[cls])
#      30 org = [x1, y1]
#      31 font = cv2.FONT_HERSHEY_SIMPLEX
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
class ObjectDetection:
    def __init__(self):
        self.model = self.load_model()
        self.class_names = ["person"]
    
    def load_model(self):
        model = YOLO("yolo-Weights/yolov8n.pt")
        model.fuse()
        
        return model
    
    def plot_boxes(self):

        classNames = [
            "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train", "truck", "boat",
            "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
            "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack",
            "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball",
            "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket",
            "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
            "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake",
            "chair", "couch", "potted plant", "bed", "dining table", "toilet", "TV", "laptop",
            "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink",
            "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier",
            "toothbrush"
        ]

        person_confidence = 0
        person_detected = False
        cv2.namedWindow("preview")
        vc = cv2.VideoCapture(0)

        if vc.isOpened():
            rval, frame = vc.read()
        else:
            rval = False

        while rval:

            results = model(frame, stream=True)

            for r in results:
                boxes = r.boxes

                for box in boxes:
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

                    confidence = math.ceil((box.conf[0]*100))/100
                    print("Confidence --->",confidence)

                    cls = int(box.cls[0])
                    print("Class name -->", classNames[cls])

                    org = [x1, y1]
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    fontScale = 1
                    color = (255, 0, 0)
                    thickness = 2

                    cv2.putText(frame, classNames[cls], org, font, fontScale, color, thickness)

                    if classNames[cls] == "person":
                        person_confidence = confidence
                        person_detected = True

            cv2.imshow("preview", frame)
            rval, frame = vc.read()
            key = cv2.waitKey(20)
            if key == 27: # exit on ESC
                break

        vc.release()
        cv2.destroyWindow("preview")

        return person_detected, person_confidence
    
def detect_person():
    obj = ObjectDetection()
    person_detected, person_confidence = obj.plot_boxes()
    
    return person_detected, person_confidence

detect_person()
# Out:
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# 0: 480x640 1 person, 88.0ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.6ms preprocess, 88.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.0ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.6ms preprocess, 69.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.7ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.9ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.5ms preprocess, 58.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.0ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.4ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.4ms preprocess, 74.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.3ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.3ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.6ms preprocess, 55.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 78.4ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.3ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.1ms preprocess, 63.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 71.9ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.1ms preprocess, 71.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 64.8ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.4ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.5ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.8ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.1ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.1ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.6ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.4ms preprocess, 55.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 76.6ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.3ms preprocess, 76.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 75.9ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.7ms preprocess, 75.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.7ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.5ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.7ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.1ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.7ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.9ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.5ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.5ms preprocess, 67.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.1ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.1ms preprocess, 68.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.0ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.5ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.6ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.7ms preprocess, 86.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.1ms preprocess, 69.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.7ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.4ms preprocess, 65.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.1ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.4ms preprocess, 70.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.1ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.6ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.7ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.4ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.5ms preprocess, 68.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.3ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.2ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.1ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.9ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.0ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.1ms preprocess, 70.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.1ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.4ms preprocess, 70.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 71.1ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.4ms preprocess, 71.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 98.3ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.5ms preprocess, 98.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 91.6ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 91.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 77.3ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.6ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.2ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 75.7ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.5ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.1ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.8ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.3ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.7ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.5ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.1ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.9ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.9ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.0ms
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.5ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.1ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.7ms preprocess, 61.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.3ms preprocess, 60.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.7ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.7ms preprocess, 65.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.0ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.2ms preprocess, 63.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.9ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.4ms preprocess, 66.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.0ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.4ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.3ms
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 60.3ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 60.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.3ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.9ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 64.4ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.6ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 67.3ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.7ms preprocess, 67.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.3ms
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.3ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.6ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.3ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.2ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.6ms preprocess, 73.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.8ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.2ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.4ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.4ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 60.4ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 64.0ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.9ms preprocess, 64.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.2ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.6ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.5ms preprocess, 83.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.8ms
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.5ms preprocess, 74.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.2ms
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.8ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.6ms
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.8ms preprocess, 87.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.3ms
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.6ms preprocess, 70.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.1ms
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.6ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.0ms
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.3ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.5ms
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.2ms preprocess, 67.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Confidence ---> 0.48
# Class name --> person
# Speed: 1.3ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.1ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.0ms
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.4ms preprocess, 67.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.8ms
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.4ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.3ms preprocess, 61.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.0ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.1ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.3ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.5ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.9ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.9ms preprocess, 66.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.2ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.4ms preprocess, 61.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.3ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.7ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.8ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.0ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.9ms preprocess, 76.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.4ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.2ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.2ms preprocess, 57.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.3ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.9ms preprocess, 59.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.6ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.2ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.3ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.2ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.3ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 59.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.2ms preprocess, 59.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.1ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.2ms preprocess, 59.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.2ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 2.0ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 69.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> refrigerator
# Speed: 1.4ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.7ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.4ms preprocess, 61.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.8ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.3ms preprocess, 57.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.5ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 59.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.3ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.1ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.2ms preprocess, 56.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 55.2ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.1ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.5ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.4ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.9ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.3ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.7ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.7ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.4ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.2ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.9ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.1ms preprocess, 53.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.2ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 56.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 57.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.3ms preprocess, 60.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.1ms preprocess, 54.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.9ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.8ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.1ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.8ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.4ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.1ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.4ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.4ms preprocess, 74.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.4ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.2ms preprocess, 81.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 52.9ms
# Confidence ---> 0.48
# Class name --> remote
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.2ms preprocess, 52.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 54.5ms
# Confidence ---> 0.45
# Class name --> remote
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.3ms preprocess, 54.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 58.2ms
# Confidence ---> 0.82
# Class name --> remote
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.6ms preprocess, 58.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 59.0ms
# Confidence ---> 0.8
# Class name --> remote
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 58.2ms
# Confidence ---> 0.8
# Class name --> remote
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 58.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 54.3ms
# Confidence ---> 0.82
# Class name --> remote
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.4ms preprocess, 54.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 58.2ms
# Confidence ---> 0.87
# Class name --> remote
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.1ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 54.4ms
# Confidence ---> 0.87
# Class name --> remote
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.4ms preprocess, 54.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 60.1ms
# Confidence ---> 0.84
# Class name --> remote
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.3ms preprocess, 60.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 58.6ms
# Confidence ---> 0.85
# Class name --> remote
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.0ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 56.3ms
# Confidence ---> 0.83
# Class name --> remote
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 54.8ms
# Confidence ---> 0.84
# Class name --> remote
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.3ms preprocess, 54.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 61.4ms
# Confidence ---> 0.7
# Class name --> remote
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.3ms preprocess, 61.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 62.5ms
# Confidence ---> 0.76
# Class name --> remote
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.4ms preprocess, 62.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 56.2ms
# Confidence ---> 0.7
# Class name --> remote
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.0ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 53.0ms
# Confidence ---> 0.69
# Class name --> remote
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 1.0ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 52.8ms
# Confidence ---> 0.72
# Class name --> remote
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 1.2ms preprocess, 52.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 56.0ms
# Confidence ---> 0.71
# Class name --> remote
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.5
# Class name --> cell phone
# Speed: 1.5ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 54.5ms
# Confidence ---> 0.7
# Class name --> remote
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Speed: 0.9ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 56.2ms
# Confidence ---> 0.68
# Class name --> remote
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 1 cell phone, 53.7ms
# Confidence ---> 0.72
# Class name --> remote
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 73.1ms
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> person
# Speed: 1.2ms preprocess, 73.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 71.7ms
# Confidence ---> 0.66
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.7ms preprocess, 71.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 55.8ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 55.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.8ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.2ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.6ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.0ms preprocess, 51.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.1ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.3ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 57.7ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.49
# Class name --> remote
# Speed: 1.7ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 77.6ms
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.2ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 60.9ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.2ms preprocess, 60.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 56.1ms
# Confidence ---> 0.78
# Class name --> cell phone
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.1ms preprocess, 56.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 54.2ms
# Confidence ---> 0.83
# Class name --> cell phone
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.1ms preprocess, 54.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 49.7ms
# Confidence ---> 0.84
# Class name --> cell phone
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.1ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 57.6ms
# Confidence ---> 0.85
# Class name --> cell phone
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.2ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 53.8ms
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.0ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 51.7ms
# Confidence ---> 0.78
# Class name --> cell phone
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.0ms preprocess, 51.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 53.5ms
# Confidence ---> 0.72
# Class name --> cell phone
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.1ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.3ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.2ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.3ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.1ms preprocess, 59.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.4ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.2ms preprocess, 56.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.0ms preprocess, 55.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.1ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.0ms preprocess, 55.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 62.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.5ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.5ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.4ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.4ms preprocess, 57.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.2ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.3ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.8ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.6ms preprocess, 62.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.5ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.3ms preprocess, 57.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.3ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.8ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.6ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.5ms preprocess, 60.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 56.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.0ms preprocess, 53.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.9ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.6ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.3ms preprocess, 61.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.7ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.0ms preprocess, 58.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.9ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.4ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.7ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.3ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.4ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 56.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.7
# Class name --> bottle
# Speed: 1.4ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 71.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.68
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.3ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 68.8ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.71
# Class name --> remote
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.4ms preprocess, 68.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 61.8ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.4ms preprocess, 61.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 54.4ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.66
# Class name --> remote
# Speed: 1.0ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 52.4ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.1ms preprocess, 52.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 60.2ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.2ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 62.0ms
# Confidence ---> 0.7
# Class name --> remote
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.0ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 57.1ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 55.1ms
# Confidence ---> 0.68
# Class name --> remote
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.0ms preprocess, 55.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 53.6ms
# Confidence ---> 0.73
# Class name --> remote
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.1ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 51.5ms
# Confidence ---> 0.73
# Class name --> remote
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.3ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 58.8ms
# Confidence ---> 0.71
# Class name --> remote
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.2ms preprocess, 58.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 57.0ms
# Confidence ---> 0.72
# Class name --> remote
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.1ms preprocess, 57.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 52.4ms
# Confidence ---> 0.75
# Class name --> remote
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 52.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 58.8ms
# Confidence ---> 0.73
# Class name --> remote
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 58.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 59.1ms
# Confidence ---> 0.61
# Class name --> remote
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.7ms preprocess, 59.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 82.1ms
# Confidence ---> 0.66
# Class name --> remote
# Confidence ---> 0.6
# Class name --> person
# Speed: 2.5ms preprocess, 82.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 57.0ms
# Confidence ---> 0.64
# Class name --> remote
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 1.3ms preprocess, 57.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 55.6ms
# Confidence ---> 0.67
# Class name --> remote
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 1.2ms preprocess, 55.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 cell phone, 55.5ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.61
# Class name --> remote
# Confidence ---> 0.48
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 1.0ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 53.4ms
# Confidence ---> 0.75
# Class name --> remote
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.56
# Class name --> cell phone
# Speed: 1.2ms preprocess, 53.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 53.1ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Speed: 1.1ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 cell phone, 1 toothbrush, 54.5ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.63
# Class name --> remote
# Confidence ---> 0.45
# Class name --> toothbrush
# Confidence ---> 0.38
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.4ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 66.2ms
# Confidence ---> 0.77
# Class name --> remote
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> refrigerator
# Speed: 1.3ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 1 toothbrush, 72.4ms
# Confidence ---> 0.69
# Class name --> remote
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.46
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> refrigerator
# Speed: 1.7ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 70.0ms
# Confidence ---> 0.81
# Class name --> remote
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> refrigerator
# Speed: 1.6ms preprocess, 70.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 54.7ms
# Confidence ---> 0.85
# Class name --> remote
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.5
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> refrigerator
# Speed: 1.1ms preprocess, 54.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 cell phone, 1 refrigerator, 1 toothbrush, 56.1ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.55
# Class name --> toothbrush
# Confidence ---> 0.48
# Class name --> remote
# Confidence ---> 0.42
# Class name --> refrigerator
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.1ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 cell phone, 1 refrigerator, 1 toothbrush, 55.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.54
# Class name --> toothbrush
# Confidence ---> 0.44
# Class name --> remote
# Confidence ---> 0.39
# Class name --> refrigerator
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.2ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 58.4ms
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> refrigerator
# Speed: 1.2ms preprocess, 58.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 cell phone, 1 refrigerator, 57.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.6
# Class name --> remote
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> refrigerator
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 1.2ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 54.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> remote
# Confidence ---> 0.62
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> refrigerator
# Speed: 1.2ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 55.7ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> remote
# Confidence ---> 0.6
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> refrigerator
# Speed: 1.2ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 1 refrigerator, 55.9ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.72
# Class name --> remote
# Confidence ---> 0.63
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> refrigerator
# Speed: 1.3ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 refrigerator, 1 toothbrush, 57.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.37
# Class name --> refrigerator
# Confidence ---> 0.33
# Class name --> remote
# Confidence ---> 0.3
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.1ms preprocess, 57.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 remote, 1 refrigerator, 1 toothbrush, 51.8ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.36
# Class name --> toothbrush
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> refrigerator
# Confidence ---> 0.28
# Class name --> remote
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 55.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> refrigerator
# Speed: 1.2ms preprocess, 55.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 1 toothbrush, 55.6ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.42
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> refrigerator
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.2ms preprocess, 55.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 remote, 1 refrigerator, 1 toothbrush, 58.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.41
# Class name --> toothbrush
# Confidence ---> 0.37
# Class name --> refrigerator
# Confidence ---> 0.35
# Class name --> remote
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.0ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 toothbrush, 54.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.55
# Class name --> remote
# Confidence ---> 0.45
# Class name --> toothbrush
# Speed: 1.0ms preprocess, 54.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 toothbrush, 55.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.67
# Class name --> remote
# Confidence ---> 0.34
# Class name --> toothbrush
# Speed: 1.2ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 1 toothbrush, 50.8ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> refrigerator
# Confidence ---> 0.39
# Class name --> toothbrush
# Speed: 1.1ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.9ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.2ms preprocess, 62.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.9ms preprocess, 58.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.0ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 55.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 78.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.6ms preprocess, 70.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.3ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.1ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.9ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.1ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.6ms preprocess, 59.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.4ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.8ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 58.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.5ms preprocess, 54.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.9ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.2ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.4ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.5ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.3ms preprocess, 53.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 55.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 53.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.8ms preprocess, 68.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.1ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.2ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.8ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.4ms preprocess, 69.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 64.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.7ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.1ms preprocess, 64.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.3ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.4ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.9ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.2ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.2ms preprocess, 56.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# (True, 0.77)

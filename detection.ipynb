# %%
from ultralytics import YOLO
import cv2
import math

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
# Out:
# True

# %%
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person"]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 persons, 101.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.7ms preprocess, 101.7ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 79.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 3.1ms preprocess, 79.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 80.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.8ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 80.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.5ms preprocess, 80.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 70.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.7ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.2ms preprocess, 68.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 66.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.7ms preprocess, 66.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.6ms preprocess, 67.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.4ms preprocess, 63.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.5ms preprocess, 64.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 73.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.5ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.6ms preprocess, 67.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.5ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.8ms preprocess, 65.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.7ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.6ms preprocess, 68.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 66.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.5ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 75.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.4ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 107.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.6ms preprocess, 107.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 101.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 2.8ms preprocess, 101.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 80.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.5ms preprocess, 80.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 71.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 2.1ms preprocess, 71.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 75.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 2.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.9ms preprocess, 68.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 97.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.5ms preprocess, 97.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 77.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 4.5ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.8ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.5ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 2.1ms preprocess, 68.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 59.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.3ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.5ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.4ms preprocess, 63.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 53.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.3ms preprocess, 53.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 55.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.7ms preprocess, 55.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.3ms preprocess, 62.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 53.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.1ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.2ms preprocess, 57.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.5ms preprocess, 64.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.3ms preprocess, 57.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.6ms preprocess, 63.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.6ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.9ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.5ms preprocess, 61.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.3ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.4ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.4ms preprocess, 63.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 71.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.0ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 70.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.4ms preprocess, 70.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.8ms preprocess, 60.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.5ms preprocess, 61.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.6ms preprocess, 62.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.3ms preprocess, 62.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.5ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 58.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.6ms preprocess, 58.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.1ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.7ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.4ms preprocess, 61.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.3ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.4ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.5ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.8ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.8ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 2.3ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 55.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.8ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.8ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.0ms preprocess, 60.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.6ms preprocess, 63.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.3ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 60.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.3ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 58.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.5ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 60.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.2ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.6ms preprocess, 63.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 52.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.1ms preprocess, 52.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 58.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.2ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 74.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.2ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 71.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.9ms preprocess, 71.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 65.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.1ms preprocess, 65.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.2ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 59.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.6ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 2.0ms preprocess, 64.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.4ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.3ms preprocess, 61.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.8ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.6ms preprocess, 65.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 58.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.3ms preprocess, 58.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.9ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 62.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.4ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 60.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.6ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 64.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.3ms preprocess, 64.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.6ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 58.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.6ms preprocess, 58.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 1.7ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 61.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.6ms preprocess, 61.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 2.0ms preprocess, 56.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.3ms preprocess, 62.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.6ms preprocess, 61.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.8ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.1ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.6ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.6ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.3ms preprocess, 65.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.4ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 92.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 92.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 72.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.0ms preprocess, 72.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.6ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 62.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.8ms preprocess, 62.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 64.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.8ms preprocess, 64.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 66.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.3ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 66.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.3ms preprocess, 66.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 59.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.5ms preprocess, 59.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 2.1ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 57.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.5ms preprocess, 57.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 57.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.3ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 63.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.4ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 63.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.0ms preprocess, 63.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.6ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 62.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.8ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 58.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.3ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 63.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.5ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 60.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.6ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 63.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.6ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 65.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.2ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 64.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.4ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.7ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.2ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.0ms preprocess, 61.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.4ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 1.7ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 75.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 1.8ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 74.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.7ms preprocess, 74.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.6ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.3ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 1.8ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.5ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.9ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.5ms preprocess, 58.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 2.2ms preprocess, 58.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.3ms preprocess, 61.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.3ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 2.2ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 1.1ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.7ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.3ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.4ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 61.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 58.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 55.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.7ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.5ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.2ms preprocess, 56.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.6ms preprocess, 60.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.5ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.1ms preprocess, 61.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.5ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.2ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 1.2ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 73.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.6ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.6ms preprocess, 70.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 2.0ms preprocess, 70.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.7ms preprocess, 80.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 71.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.8ms preprocess, 71.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.6ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.6ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
